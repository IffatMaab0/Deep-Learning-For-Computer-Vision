# %% [markdown]
# <a href="https://colab.research.google.com/github/IffatMaab0/Deep-Learning-For-Computer-Vision/blob/main/TensorFlow/BuildingNeuralNetworks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import pandas as pd

# %%
df = pd.read_csv("Cars.csv")

# %%
X = df[["Mileage", "Age", "Horsepower", "ServiceScore"]]
y = df["Price"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2
)

# %%
normalizer = tf.keras.layers.Normalization()
normalizer.adapt(X_train.values)

# %%
model = tf.keras.Sequential([
    normalizer,
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(1)
])

# %%
model.compile(optimizer='adam', loss='mse')

# %%
model.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 2630905088.0000
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2630892800.0000
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2630880000.0000
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2630865920.0000
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2630851072.0000
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2630834688.0000
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2630817024.0000
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2630797568.0000
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2630775808.0000
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2630752000.0000
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2630725376.0000
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2630695936.0000
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2630662656.0000
# ...

# %%
model.predict([[120000, 5, 200, 7]])
